# %%
import json
from collections import Counter
import random

# %%
def getAnswer(name):
    path = name + ".json"
    with open(path, 'r') as f:
        data = json.load(f)

    # Преобразование данных из словаря в список

    arr = [round(num, 6) for num in data if isinstance(num, (int, float))]
    # Нахождение самых часто встречающихся чисел
    counts = Counter(arr)
    max_count = max(counts.values())

    # Определение индекса первого появления числа и его количество повторений
    result = []
    for num in counts:
        index = arr.index(num)
        count = counts[num]
        if count == max_count:
            result.append([index, num, count])

    print(result)
    path = name + "_Answer.json"
    with open(path, 'w') as f:
        json.dump(result, f)

# %%
def randomFillJson(name, n):
    random_numbers = [random.uniform(-1000000, 1000000) for _ in range(n)]
    a = random.uniform(-1000000, 1000000)
    random_numbers.append(a)
    random_numbers.append(a)
    #random_numbers.append("asdsad")
    # Запись массива в файл JSON без ключа
    output = [num for num in random_numbers]
    path = name + ".json"
    with open(path, 'w') as f:
        json.dump(output, f)

# %%
#TEST 2
name = "Test2"
path = name + ".json"
with open(path, 'w') as f:
    pass
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 3
name = "Test3"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(0)]
    output.append("asdsad")
    output.append('a')
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 4
name = "Test4_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(0)]
    output.append(9876543456789)
    output.append(83758759493054)
    output.append(76765678371213.123213)
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 5
name = "Test4_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(0)]
    output.append(9876543456789)
    output.append(83758759493054)
    output.append(76765678371213.123213)
    output.append("asdsad")
    output.append('a')
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 6
name = "Test5_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(1030)]
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 7
name = "Test5_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(1080)]
    output.append(9876543456789)
    output.append(76765678371213.123213)
    output.append("asdsad")
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 8
name = "Test6_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(150)]
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[0, -112201.852089, 1], [1, 283213.232305, 1], [2, 635236.063017, 1], [3, -388434.257291, 1], [4, 197773.86779, 1], [5, 827638.847265, 1], [6, 250955.353641, 1], [7, -343526.144998, 1], [8, 162159.030755, 1], [9, 211971.837379, 1], [10, 234322.41511, 1], [11, -806280.471324, 1], [12, 129104.366507, 1], [13, -380923.983233, 1], [14, 358033.286579, 1], [15, 789639.953547, 1], [16, -119102.261499, 1], [17, 187161.409403, 1], [18, 8667.210029, 1], [19, -240122.205826, 1], [20, 699665.429668, 1], [21, 537281.4258, 1], [22, 969150.285541, 1], [23, 734758.633211, 1], [24, -613489.380287, 1], [25, 607526.321685, 1], [26, -607060.409083, 1], [27, 783312.135863, 1], [28, -176905.563668, 1], [29, -97616.745598, 1], [30, -767054.18759, 1], [31, 666580.206914, 1], [32, -322443.071835, 1], [33, 112951.03911, 1], [34, -151927.950753, 1], [35, 227436.506385, 1], [36, 155527.306207, 1], [37, 80201.111362, 1], [38, 843661.813109, 1], [39, 376542.731921, 1], [40, -9270.661235, 1], [41, -396642.821189, 1], [42, 815509.859652, 1], [43, -639895.168166, 1], [44, -634633.293381, 1], [45, 435553.279105, 1], [46, 836888.858799, 1], [47, 264942.405659, 1], [48, 741435.010451, 1], [49, 640660.994691, 1], [50, 238834.373135, 1], [51, 924960.357496, 1], [52, -2182.361459, 1], [53, -371592.088152, 1], [54, -509786.61908, 1], [55, -258815.332871, 1], [56, 139030.269742, 1], [57, 856445.98721, 1], [58, 125238.662765, 1], [59, -397563.78796, 1], [60, -47504.70829, 1], [61, 403059.229582, 1], [62, -668920.121377, 1], [63, 552397.149926, 1], [64, -397416.988715, 1], [65, 267359.561015, 1], [66, -634948.331528, 1], [67, -963646.978831, 1], [68, 46607.025483, 1], [69, -976982.146083, 1], [70, 381246.722812, 1], [71, -41943.589789, 1], [72, -897863.490294, 1], [73, -52146.152787, 1], [74, -357887.794796, 1], [75, -720368.936968, 1], [76, -875162.087012, 1], [77, -26156.547541, 1], [78, 261767.607864, 1], [79, -965994.883584, 1], [80, -706277.777324, 1], [81, 884096.358345, 1], [82, 150802.833217, 1], [83, 75679.049977, 1], [84, -553650.916176, 1], [85, 324399.284858, 1], [86, -906999.67212, 1], [87, -867628.676303, 1], [88, 405254.331547, 1], [89, 254154.984432, 1], [90, 810169.278078, 1], [91, 427508.839449, 1], [92, 407986.229995, 1], [93, -246516.215253, 1], [94, 364118.217531, 1], [95, 913428.623155, 1], [96, -842208.130068, 1], [97, 6255.797959, 1], [98, 116018.518656, 1], [99, -276231.570304, 1], [100, -991300.637162, 1], [101, -13748.619041, 1], [102, 197789.604045, 1], [103, -785502.639543, 1], [104, -236023.221357, 1], [105, -413543.92161, 1], [106, -433992.62622, 1], [107, 261012.908061, 1], [108, 834656.565399, 1], [109, 657615.884853, 1], [110, -962204.880912, 1], [111, -39621.839833, 1], [112, -934693.94366, 1], [113, 957482.427011, 1], [114, -281951.600803, 1], [115, 567524.877105, 1], [116, -121274.506472, 1], [117, 551509.708034, 1], [118, -642955.700955, 1], [119, 660332.768331, 1], [120, 192764.520851, 1], [121, 145055.290299, 1], [122, 948275.964404, 1], [123, 398018.219502, 1], [124, 710345.926476, 1], [125, -762207.033616, 1], [126, -511869.611123, 1], [127, -390102.425487, 1], [128, -54328.713772, 1], [129, -114887.540259, 1], [130, 150104.166843, 1], [131, -72339.964387, 1], [132, 591808.017525, 1], [133, -129700.401002, 1], [134, -19631.554973, 1], [135, -123445.168973, 1], [136, -115665.064602, 1], [137, -770402.304333, 1], [138, -388417.35457, 1], [139, -849585.744869, 1], [140, 865998.475671, 1], [141, -932326.641938, 1], [142, -420731.444281, 1], [143, -864003.569122, 1], [144, 231449.847334, 1], [145, -76238.156656, 1], [146, 175197.953945, 1], [147, -405228.715635, 1], [148, 769978.706887, 1], [149, -999007.977235, 1]]

# %%
#TEST 9
name = "Test6_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(250)]
    output.append("asdsad")
    output.append('d')
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[0, -326719.967153, 1], [1, -32734.092915, 1], [2, 955411.238919, 1], [3, 722292.27474, 1], [4, 824935.581612, 1], [5, -628944.496333, 1], [6, -943503.476186, 1], [7, -450096.838033, 1], [8, -62947.341063, 1], [9, -875550.592391, 1], [10, 547632.404748, 1], [11, -836756.79306, 1], [12, -901132.026305, 1], [13, -353985.254184, 1], [14, -801466.104324, 1], [15, -356821.203998, 1], [16, 467110.009667, 1], [17, -596096.916758, 1], [18, 114564.499133, 1], [19, -466264.751671, 1], [20, 344077.276635, 1], [21, -410803.462061, 1], [22, 258036.465114, 1], [23, 351246.015923, 1], [24, -453613.034085, 1], [25, 492580.225671, 1], [26, 509053.771798, 1], [27, -259787.52228, 1], [28, -499923.250849, 1], [29, -709386.525491, 1], [30, -529636.200569, 1], [31, 742392.271487, 1], [32, -93112.802292, 1], [33, -862267.313785, 1], [34, 846783.260528, 1], [35, -113688.588448, 1], [36, -354201.606912, 1], [37, -373898.751747, 1], [38, 848396.008099, 1], [39, 816513.714471, 1], [40, -340242.093255, 1], [41, -805377.351806, 1], [42, -237944.724684, 1], [43, 699140.737269, 1], [44, -929810.648138, 1], [45, 546390.252817, 1], [46, 451872.66015, 1], [47, 627579.358719, 1], [48, 889454.968201, 1], [49, -890093.918506, 1], [50, -558657.491808, 1], [51, -942587.711739, 1], [52, 175720.129514, 1], [53, 584147.837009, 1], [54, -399747.562232, 1], [55, 550033.346367, 1], [56, 620940.274955, 1], [57, 779623.973403, 1], [58, 811690.281517, 1], [59, 64761.040852, 1], [60, 333129.99228, 1], [61, 245834.247183, 1], [62, 373183.317477, 1], [63, 767000.190084, 1], [64, 125767.22951, 1], [65, 275539.845893, 1], [66, -319603.872411, 1], [67, 465869.273856, 1], [68, -804370.255252, 1], [69, -418494.95687, 1], [70, 899846.643236, 1], [71, -667781.600814, 1], [72, 969867.898267, 1], [73, 655081.611013, 1], [74, -551144.732241, 1], [75, 344201.665727, 1], [76, 973135.925741, 1], [77, -724054.716397, 1], [78, -817004.803644, 1], [79, 260974.821666, 1], [80, 548973.118901, 1], [81, 644890.466087, 1], [82, 896068.979866, 1], [83, 814351.811727, 1], [84, -620071.26332, 1], [85, -62396.948534, 1], [86, -155508.933106, 1], [87, 321211.488549, 1], [88, -925108.580067, 1], [89, 208498.162018, 1], [90, -235608.411495, 1], [91, 809139.37663, 1], [92, -102298.975384, 1], [93, 785537.088962, 1], [94, 634763.082589, 1], [95, -360083.439764, 1], [96, 152606.51969, 1], [97, -449361.981951, 1], [98, -852958.451368, 1], [99, 989245.204593, 1], [100, -928038.48346, 1], [101, -437336.321928, 1], [102, -348192.733238, 1], [103, 19304.33915, 1], [104, -323987.891813, 1], [105, -34689.496339, 1], [106, 967379.536908, 1], [107, 656262.190619, 1], [108, 502208.792652, 1], [109, 817930.365854, 1], [110, -261352.195865, 1], [111, 696150.666313, 1], [112, -523846.082642, 1], [113, -23135.473598, 1], [114, -521635.07391, 1], [115, 362162.639036, 1], [116, 707116.60162, 1], [117, 513735.987405, 1], [118, -903294.568139, 1], [119, -895589.375958, 1], [120, 22498.442005, 1], [121, 457823.121354, 1], [122, 521998.552513, 1], [123, 264928.261612, 1], [124, -199463.294673, 1], [125, -928893.636016, 1], [126, 464015.128252, 1], [127, -108496.401042, 1], [128, -691506.860362, 1], [129, 900105.116714, 1], [130, 928759.263041, 1], [131, 710160.39748, 1], [132, 464917.839621, 1], [133, -120888.488276, 1], [134, -260863.912446, 1], [135, 875218.881052, 1], [136, 647308.074271, 1], [137, 517459.234522, 1], [138, -296497.241517, 1], [139, 998017.080581, 1], [140, 685321.459829, 1], [141, 568311.105426, 1], [142, 820174.721779, 1], [143, -660012.832409, 1], [144, -954439.960408, 1], [145, 730372.279063, 1], [146, -983945.177773, 1], [147, 800864.04047, 1], [148, -453137.38051, 1], [149, -935938.229956, 1], [150, -760429.404976, 1], [151, -25537.449341, 1], [152, 417395.356272, 1], [153, -538918.384821, 1], [154, -287232.383413, 1], [155, 17843.728242, 1], [156, -857578.007735, 1], [157, -692156.786937, 1], [158, 907210.989925, 1], [159, -178254.23538, 1], [160, 407769.229375, 1], [161, -55352.242983, 1], [162, -74 ...

# %%
#TEST 10 самый проходимый 
name = "Test7"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-1000000, 1000000) for _ in range(350)]
    for i in range (random.randint(1, 50)):
        output.append(output[random.randint(0,349 + i)])
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[195, -395186.547421, 4]]

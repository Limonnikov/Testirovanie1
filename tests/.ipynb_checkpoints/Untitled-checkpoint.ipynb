# %%
import json
from collections import Counter
import random
import math

# %%
def getAnswer(name):
    path = name + ".json"
    with open(path, 'r') as f:
        data = json.load(f)

    # Преобразование данных из словаря в список

    arr = [math.floor(num * 1000000) / 1000000 for num in data if isinstance(num, (int, float))]
    # Нахождение самых часто встречающихся чисел
    counts = Counter(arr)
    max_count = max(counts.values())

    # Определение индекса первого появления числа и его количество повторений
    result = []
    for num in counts:
        index = arr.index(num)
        count = counts[num]
        if count == max_count:
            result.append([index, num, count])

    print(result)
    path = name + "_Answer.json"
    with open(path, 'w') as f:
        json.dump(result, f)

# %%
def randomFillJson(name, n):
    random_numbers = [random.uniform(-1000000, 1000000) for _ in range(n)]
    a = random.uniform(-1000000, 1000000)
    random_numbers.append(a)
    random_numbers.append(a)
    #random_numbers.append("asdsad")
    # Запись массива в файл JSON без ключа
    output = [num for num in random_numbers]
    path = name + ".json"
    with open(path, 'w') as f:
        json.dump(output, f)

# %%
#TEST 2
name = "Test2"
path = name + ".json"
with open(path, 'w') as f:
    pass
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 3
name = "Test3"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+38, 3.40282e+38) for _ in range(0)]
    output.append("asdsad")
    output.append('a')
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 4
name = "Test4_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+38, 3.40282e+38) for _ in range(0)]
    output.append(3.40282e+39)
    output.append(3.40282e+40)
    output.append(-3.40282e+39)
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 5
name = "Test4_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+38, 3.40282e+38) for _ in range(0)]
    output.append(3.40282e+39)
    output.append(3.40282e+40)
    output.append(-3.40282e+39)
    output.append("asdsad")
    output.append('a')
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 6
name = "Test5_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+38, 3.40282e+38) for _ in range(1030)]
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 7
name = "Test5_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+38, 3.40282e+38) for _ in range(1080)]
    output.append("asdsad")
    json.dump(output, f)
    
path = name + "_Answer.json"
with open(path, 'w') as f:
    pass

# %%
#TEST 8
name = "Test6_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(150)]
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[0, -2.762214273385698e+30, 1], [1, 4.9794254500451824e+29, 1], [2, -3.329430081874295e+30, 1], [3, -1.6946987227430333e+30, 1], [4, -2.2104969789043712e+30, 1], [5, 7.526539199667657e+29, 1], [6, 5.421573621481755e+29, 1], [7, -2.8742841514112393e+30, 1], [8, 2.064966586745758e+30, 1], [9, -9.163496577667868e+29, 1], [10, 2.82532888853447e+30, 1], [11, 3.7411127967269125e+29, 1], [12, -3.2086066051478347e+30, 1], [13, 2.673688887273506e+30, 1], [14, 2.788332758551554e+30, 1], [15, -1.9410775755162295e+30, 1], [16, -1.940512515601221e+30, 1], [17, -3.350118793849778e+30, 1], [18, 3.394200267308125e+30, 1], [19, 5.092677430694956e+29, 1], [20, 1.9355961629283342e+30, 1], [21, -2.3828789327646392e+30, 1], [22, 9.972568815416093e+29, 1], [23, 1.628837544006906e+30, 1], [24, 2.715390862497211e+30, 1], [25, 8.712657027574348e+29, 1], [26, -6.738705728831931e+29, 1], [27, 2.2924465268906532e+30, 1], [28, 6.25322910550561e+28, 1], [29, 8.658287537337528e+29, 1], [30, -6.946694795843449e+29, 1], [31, -1.9899013787228544e+30, 1], [32, 2.3507661078176752e+30, 1], [33, 3.044379463519281e+29, 1], [34, 2.974531434869594e+30, 1], [35, -1.796304433493303e+30, 1], [36, -2.6086690028203027e+30, 1], [37, 2.9309570083364715e+30, 1], [38, -1.681368028998745e+30, 1], [39, -1.442284513680311e+30, 1], [40, 1.8464229813354547e+30, 1], [41, -2.0569429735246008e+30, 1], [42, -3.354834585155643e+30, 1], [43, 3.080434194734231e+30, 1], [44, 1.8761989221472536e+30, 1], [45, -1.724287340960413e+30, 1], [46, -3.565496545353283e+29, 1], [47, 2.1324576059314312e+30, 1], [48, 9.825842108397506e+29, 1], [49, -1.9694069392273322e+30, 1], [50, -2.239666686640561e+30, 1], [51, -2.2515693594945522e+30, 1], [52, 2.836566889574501e+30, 1], [53, -3.350725434900991e+30, 1], [54, -2.890948450566176e+30, 1], [55, 9.977123683250616e+29, 1], [56, -1.7300003257131613e+30, 1], [57, -2.4257185207104022e+30, 1], [58, -6.982291674589384e+29, 1], [59, 1.950654381244594e+30, 1], [60, -2.049869028318103e+30, 1], [61, -3.1107661136195746e+30, 1], [62, -2.4446507660691014e+29, 1], [63, 2.342023456281483e+30, 1], [64, -2.8259828666523934e+30, 1], [65, 1.2536172982263256e+30, 1], [66, -1.2334129608735954e+30, 1], [67, 2.2358111043674967e+29, 1], [68, -2.983190412853262e+30, 1], [69, 6.291198732488571e+29, 1], [70, 2.3568278932968718e+30, 1], [71, -3.331167743027749e+30, 1], [72, 3.158088107490944e+30, 1], [73, 1.6242067665965962e+29, 1], [74, 2.512957028371469e+30, 1], [75, -2.2160038732630217e+30, 1], [76, 3.3929566050829394e+30, 1], [77, 5.201124625127957e+29, 1], [78, -2.4290810963252013e+29, 1], [79, -3.093261628658591e+30, 1], [80, 5.572304279055444e+29, 1], [81, 3.0258814630479296e+30, 1], [82, 2.3673086070055813e+30, 1], [83, -1.1197640922977992e+30, 1], [84, 1.275641604810898e+30, 1], [85, -2.6584590093777445e+30, 1], [86, -1.7138675445318834e+30, 1], [87, -2.1249298148813372e+30, 1], [88, 2.789718396904184e+30, 1], [89, 8.287964299399676e+29, 1], [90, 2.4777903704636855e+30, 1], [91, -1.356118190798073e+30, 1], [92, 2.4449418503150328e+30, 1], [93, 2.4884883799576383e+30, 1], [94, 1.5980193173925833e+30, 1], [95, 2.4094893379178567e+30, 1], [96, 2.8738572187926805e+29, 1], [97, 2.8641020354454333e+30, 1], [98, 2.80804247532053e+30, 1], [99, -3.595727963571433e+29, 1], [100, -7.569303033794615e+29, 1], [101, 2.8647363602045996e+30, 1], [102, -5.184312015004873e+28, 1], [103, 1.2375273374532318e+30, 1], [104, -1.6822982830651062e+29, 1], [105, -3.0659437898841037e+30, 1], [106, 3.173967675038655e+30, 1], [107, 6.509000700962015e+28, 1], [108, -3.7876068223813834e+29, 1], [109, 1.083004186341651e+30, 1], [110, -1.9717236317797734e+30, 1], [111, 1.4953238335235559e+29, 1], [112, -2.3214377221433652e+30, 1], [113, 8.894277664748891e+29, 1], [114, -1.0737671909678353e+30, 1], [115, -2.3152016324881216e+28, 1], [116, -1.1416178784791376e+30, 1], [117, -3.585040340437401e+29, 1], [118, 3.063848547194194e+30, 1], [119, 2.270259833679406e+30, 1], [120, -6.0794291352298364e+29, 1], [12 ...

# %%
#TEST 9
name = "Test6_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(250)]
    output.append("asdsad")
    output.append('d')
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[0, 2.140260454080509e+30, 1], [1, 2.843882070891848e+30, 1], [2, -2.677539771210671e+30, 1], [3, 2.180096415377606e+29, 1], [4, -2.2273211081608365e+30, 1], [5, -1.0125912090033628e+30, 1], [6, -9.55752682231579e+29, 1], [7, 2.4225402962737326e+30, 1], [8, -1.1273100110767793e+30, 1], [9, -2.8235610993663235e+30, 1], [10, 3.0959510032368154e+30, 1], [11, -1.403602680469133e+30, 1], [12, 2.0710058674081694e+30, 1], [13, -2.30127701021307e+30, 1], [14, -5.235534518806227e+29, 1], [15, 1.644271097476198e+29, 1], [16, -1.3181381342589999e+29, 1], [17, -2.086445286321003e+30, 1], [18, 7.77109687200179e+29, 1], [19, 2.435217023927061e+30, 1], [20, -5.939252697295023e+29, 1], [21, -1.794557501669611e+29, 1], [22, -6.450021565182696e+29, 1], [23, -7.595663874065048e+29, 1], [24, -1.867496683333213e+30, 1], [25, -3.0684664437981624e+30, 1], [26, -1.5431202050732747e+30, 1], [27, 3.1218485276543846e+30, 1], [28, -1.80962826939698e+30, 1], [29, 2.1666573299556455e+30, 1], [30, 2.219952827503181e+28, 1], [31, -1.4119946224615225e+29, 1], [32, 2.4670171336511533e+30, 1], [33, 1.3169099309715367e+30, 1], [34, -1.1763279102955742e+30, 1], [35, -3.236725130305203e+30, 1], [36, -2.658144701846482e+30, 1], [37, 9.117088592360952e+29, 1], [38, 2.738966801278537e+30, 1], [39, -2.4896325446565635e+30, 1], [40, -3.298364107778374e+30, 1], [41, -1.953234870617572e+30, 1], [42, 8.130116852066246e+29, 1], [43, -3.6596669051969724e+29, 1], [44, -9.79116962829393e+29, 1], [45, -3.3641327595054207e+30, 1], [46, -1.3609014713818247e+30, 1], [47, 1.9840982633890767e+30, 1], [48, -3.662164529954275e+29, 1], [49, 3.3218702025175336e+30, 1], [50, 2.813691519354e+30, 1], [51, -9.759227089874725e+29, 1], [52, -5.59578259775247e+28, 1], [53, -1.660333793854516e+30, 1], [54, 2.5083340183048414e+30, 1], [55, 4.854659257364545e+29, 1], [56, 5.0992733851311355e+29, 1], [57, 1.8748064585164197e+30, 1], [58, -7.008115627503275e+29, 1], [59, -4.4436982301585e+29, 1], [60, -1.2731661039679613e+30, 1], [61, 3.203988599732769e+30, 1], [62, -3.1297077733359896e+30, 1], [63, 5.1657995828431555e+28, 1], [64, -9.304547202215064e+29, 1], [65, -1.139082430159419e+30, 1], [66, -1.1204195235005266e+30, 1], [67, 2.3145550770783833e+30, 1], [68, 1.9618288755499655e+30, 1], [69, 2.4209425329432836e+30, 1], [70, -2.9821896180158446e+30, 1], [71, -1.904882623782259e+30, 1], [72, 3.383605220033227e+30, 1], [73, 6.238256221006778e+29, 1], [74, -3.01320104417541e+30, 1], [75, 2.5353738987739374e+30, 1], [76, -6.3257610903304554e+29, 1], [77, -2.845759822165832e+30, 1], [78, -1.8701436188514132e+30, 1], [79, 2.3297545608693888e+30, 1], [80, -1.265943708065598e+30, 1], [81, 1.8289138818829353e+30, 1], [82, -2.1816217264318883e+30, 1], [83, 1.8882172623958446e+30, 1], [84, -1.9723013987897318e+30, 1], [85, -1.4709691772174472e+30, 1], [86, 2.678758030342819e+30, 1], [87, 7.227143159726852e+29, 1], [88, -5.680088322044365e+27, 1], [89, 2.533490074844268e+30, 1], [90, -2.1978614837656185e+30, 1], [91, 1.1614732671157446e+30, 1], [92, 3.3338799255069094e+30, 1], [93, -9.388884152158507e+29, 1], [94, -1.839145154540111e+30, 1], [95, 9.147630558959845e+29, 1], [96, -1.9675461962787296e+30, 1], [97, 3.065861645179745e+30, 1], [98, -1.8092165381724546e+30, 1], [99, -2.2219976289684217e+30, 1], [100, -1.1378008315723698e+30, 1], [101, -5.662516346836299e+29, 1], [102, 4.492034373248224e+29, 1], [103, 9.135140201526832e+29, 1], [104, -2.4402011111641654e+30, 1], [105, -7.189253944867717e+27, 1], [106, -1.6221661261018554e+29, 1], [107, 1.1109184804246864e+30, 1], [108, -5.4246160911773115e+29, 1], [109, -9.190580208541591e+29, 1], [110, 6.0291634087145396e+28, 1], [111, -3.209781671352933e+29, 1], [112, -2.6399397110803546e+30, 1], [113, 2.3328711192387e+30, 1], [114, -2.4034439976058749e+30, 1], [115, -2.2327084222100982e+29, 1], [116, 3.030311247655374e+30, 1], [117, 1.2166658849365417e+30, 1], [118, 1.9384383094844375e+29, 1], [119, 1.3579418395709153e+30, 1], [120, -2.1140266945686333e+30, 1], ...

# %%
#TEST 10 самый проходимый 
name = "Test7"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(350)]
    for i in range (random.randint(1, 50)):
        output.append(output[random.randint(0,349 + i)])
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[223, -3.318610987965028e+29, 3]]

# %%
#TEST 11 эквивалентность 
name = "Test8_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(20)]
    for i in range (random.randint(1, 4)):
        output.append(output[random.randint(0,19)])
    output.append(-3.40282e+39)
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[6, -3.0154405122195567e+30, 2], [17, 3.4767883483917016e+28, 2]]

# %%
#TEST 12 эквивалентность 
name = "Test8_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(30)]
    for i in range (random.randint(1, 5)):
        output.append(output[random.randint(0,20)])
    output.append(-3.40282e+38)
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[1, -1.9463068235859928e+30, 2], [17, -3.2608081060937217e+30, 2]]

# %%
#TEST 13 эквивалентность 
name = "Test8_3"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(40)]
    for i in range (random.randint(1, 8)):
        output.append(output[random.randint(0,20)])
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[0, 6.056077852978532e+28, 2], [4, 8.688745564773163e+28, 2], [8, 3.2878724261756754e+30, 2]]

# %%
#TEST 14 эквивалентность 
name = "Test8_4"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(50)]
    for i in range (random.randint(1, 8)):
        output.append(output[random.randint(0,20)])
    output.append(3.40282e+38)
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[14, -1.478467721133476e+30, 2], [16, 1.4107233525795716e+30, 2], [18, -1.610319122184272e+30, 2]]

# %%
#TEST 15 эквивалентность 
name = "Test8_5"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(60)]
    for i in range (random.randint(1, 8)):
        output.append(output[random.randint(0,20)])
    output.append(3.40282e+39)
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[9, 2.9472567113613106e+30, 3]]

# %%
#TEST 16 эквивалентность 
name = "Test8_6"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(70)]
    for i in range (random.randint(1, 8)):
        output.append(output[random.randint(0,20)])
    output.append("kjhgfddfghn")
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[2, -2.140561494816125e+30, 2], [11, -2.1698061170625493e+30, 2], [13, -1.9533916144088753e+30, 2], [14, -2.3238425743087698e+30, 2], [16, -2.651939847684669e+29, 2]]

# %%
#TEST 17 эквивалентность 2
name = "Test9_1"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(80)]
    for i in range (random.randint(1, 8)):
        output.append(output[random.randint(0,20)])
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[7, 1.3706321426211864e+30, 3]]

# %%
#TEST 18 эквивалентность 2
name = "Test9_2"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(1020)]
    for i in range (4):
        output.append(output[random.randint(0,20)])
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[1, 2.286307934482976e+30, 2], [8, -3.202778102434999e+30, 2], [13, 3.0437827596407326e+30, 2], [20, 3.0521948584408246e+30, 2]]

# %%
#TEST 19 эквивалентность 2
name = "Test9_3"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(1058)]
    for i in range (4):
        output.append(output[random.randint(0,20)])
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[11, 2.2363234081304587e+30, 2], [12, -2.9184352424580194e+30, 2], [13, -2.916267526378438e+30, 2], [15, -2.811488671427577e+28, 2]]

# %%
#TEST 20 уникальные значения 
name = "Test10"
path = name + ".json"
with open(path, 'w') as f:
    output = [random.uniform(-3.40282e+30, 3.40282e+30) for _ in range(0)]
    for i in range (random.randint(4, 1000)):
        output.append(i)
    json.dump(output, f)
    
getAnswer(name)
# Out:
# [[0, 0.0, 1], [1, 1.0, 1], [2, 2.0, 1], [3, 3.0, 1], [4, 4.0, 1], [5, 5.0, 1], [6, 6.0, 1], [7, 7.0, 1], [8, 8.0, 1], [9, 9.0, 1], [10, 10.0, 1], [11, 11.0, 1], [12, 12.0, 1], [13, 13.0, 1], [14, 14.0, 1], [15, 15.0, 1], [16, 16.0, 1], [17, 17.0, 1], [18, 18.0, 1], [19, 19.0, 1], [20, 20.0, 1], [21, 21.0, 1], [22, 22.0, 1], [23, 23.0, 1], [24, 24.0, 1], [25, 25.0, 1], [26, 26.0, 1], [27, 27.0, 1], [28, 28.0, 1], [29, 29.0, 1], [30, 30.0, 1], [31, 31.0, 1], [32, 32.0, 1], [33, 33.0, 1], [34, 34.0, 1], [35, 35.0, 1], [36, 36.0, 1], [37, 37.0, 1], [38, 38.0, 1], [39, 39.0, 1], [40, 40.0, 1], [41, 41.0, 1], [42, 42.0, 1], [43, 43.0, 1], [44, 44.0, 1], [45, 45.0, 1], [46, 46.0, 1], [47, 47.0, 1], [48, 48.0, 1], [49, 49.0, 1], [50, 50.0, 1], [51, 51.0, 1], [52, 52.0, 1], [53, 53.0, 1], [54, 54.0, 1], [55, 55.0, 1], [56, 56.0, 1], [57, 57.0, 1], [58, 58.0, 1], [59, 59.0, 1], [60, 60.0, 1], [61, 61.0, 1], [62, 62.0, 1], [63, 63.0, 1], [64, 64.0, 1], [65, 65.0, 1], [66, 66.0, 1], [67, 67.0, 1], [68, 68.0, 1], [69, 69.0, 1], [70, 70.0, 1], [71, 71.0, 1], [72, 72.0, 1], [73, 73.0, 1], [74, 74.0, 1], [75, 75.0, 1], [76, 76.0, 1], [77, 77.0, 1], [78, 78.0, 1], [79, 79.0, 1], [80, 80.0, 1], [81, 81.0, 1], [82, 82.0, 1], [83, 83.0, 1], [84, 84.0, 1], [85, 85.0, 1], [86, 86.0, 1], [87, 87.0, 1], [88, 88.0, 1], [89, 89.0, 1], [90, 90.0, 1], [91, 91.0, 1], [92, 92.0, 1], [93, 93.0, 1], [94, 94.0, 1], [95, 95.0, 1], [96, 96.0, 1], [97, 97.0, 1], [98, 98.0, 1], [99, 99.0, 1], [100, 100.0, 1], [101, 101.0, 1], [102, 102.0, 1], [103, 103.0, 1], [104, 104.0, 1], [105, 105.0, 1], [106, 106.0, 1], [107, 107.0, 1], [108, 108.0, 1], [109, 109.0, 1], [110, 110.0, 1], [111, 111.0, 1], [112, 112.0, 1], [113, 113.0, 1], [114, 114.0, 1], [115, 115.0, 1], [116, 116.0, 1], [117, 117.0, 1], [118, 118.0, 1], [119, 119.0, 1], [120, 120.0, 1], [121, 121.0, 1], [122, 122.0, 1], [123, 123.0, 1], [124, 124.0, 1], [125, 125.0, 1], [126, 126.0, 1], [127, 127.0, 1], [128, 128.0, 1], [129, 129.0, 1], [130, 130.0, 1], [131, 131.0, 1], [132, 132.0, 1], [133, 133.0, 1], [134, 134.0, 1], [135, 135.0, 1], [136, 136.0, 1], [137, 137.0, 1], [138, 138.0, 1], [139, 139.0, 1], [140, 140.0, 1], [141, 141.0, 1], [142, 142.0, 1], [143, 143.0, 1], [144, 144.0, 1], [145, 145.0, 1], [146, 146.0, 1], [147, 147.0, 1], [148, 148.0, 1], [149, 149.0, 1], [150, 150.0, 1], [151, 151.0, 1], [152, 152.0, 1], [153, 153.0, 1], [154, 154.0, 1], [155, 155.0, 1], [156, 156.0, 1], [157, 157.0, 1], [158, 158.0, 1], [159, 159.0, 1], [160, 160.0, 1], [161, 161.0, 1], [162, 162.0, 1], [163, 163.0, 1], [164, 164.0, 1], [165, 165.0, 1], [166, 166.0, 1], [167, 167.0, 1], [168, 168.0, 1], [169, 169.0, 1], [170, 170.0, 1], [171, 171.0, 1], [172, 172.0, 1], [173, 173.0, 1], [174, 174.0, 1], [175, 175.0, 1], [176, 176.0, 1], [177, 177.0, 1], [178, 178.0, 1], [179, 179.0, 1], [180, 180.0, 1], [181, 181.0, 1], [182, 182.0, 1], [183, 183.0, 1], [184, 184.0, 1], [185, 185.0, 1], [186, 186.0, 1], [187, 187.0, 1], [188, 188.0, 1], [189, 189.0, 1], [190, 190.0, 1], [191, 191.0, 1], [192, 192.0, 1], [193, 193.0, 1], [194, 194.0, 1], [195, 195.0, 1], [196, 196.0, 1], [197, 197.0, 1], [198, 198.0, 1], [199, 199.0, 1], [200, 200.0, 1], [201, 201.0, 1], [202, 202.0, 1], [203, 203.0, 1], [204, 204.0, 1], [205, 205.0, 1], [206, 206.0, 1], [207, 207.0, 1], [208, 208.0, 1], [209, 209.0, 1], [210, 210.0, 1], [211, 211.0, 1], [212, 212.0, 1], [213, 213.0, 1], [214, 214.0, 1]]

# %%
getAnswer("Test7")
# Out:
# [[223, -3.318610987965028e+29, 3]]
